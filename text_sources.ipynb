# %% [markdown]
# <a href="https://colab.research.google.com/github/TurkuNLP/Text_Mining_Course/blob/master/Text%20sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Where to get text data in quantities
#
# These are just a handful of selected examples of typical sources of text for various purposes. We will use some of these in the course.
#
# Aspects to consider:
#
# * Legality of redistribution
# * Topic / register skew
# * How clean text can you get?
#
# ## Web crawl data
#
# * [http://www.commoncrawl.org](http://www.commoncrawl.org)
# * Petabytes (1000s of terabytes) of crawled web content from over 10 billion pages
# * You can download it at no cost
# * You can process it in the Amazon cloud (at cost)
# * Here is a little example of raw text dump from CommonCrawl, which I took here: http://www.statmt.org/wmt16/translation-task.html
#
# <pre style="background:#F3E2A9">
# eRappu kouluttaa » videokoulutus Turkulaisten korkeakoulujen opetusteknologian koulutuksia, pääasiassa korkeakoulujen henkilökunnalle.
#
# eRappu kouluttaa
# Turkulaisten korkeakoulujen opetusteknologian koulutuksia, pääasiassa korkeakoulujen henkilökunnalle.
# No posts found.
# Search for:
# Meta
# Register
# Log in
# Entries RSS
# Comments RSS
# WordPress.org
# Categories
# koulutukset
# seminaarit
# työpajat
# Tags
# koulutus
# PLE
# seminaari
# sosiaalinen media
# työpaja
# webinaari
# Anna bloggaajalle lahja |
# Sivun alkuun | Seuraa blogia
# | Ilmoita blogista
# Höpöhöpöä
# Maailman parasta herkkukinkkukiusausta!
# 18.02.2010 - 13:27
# En muista mistä tämä ohje joskus aikoinaan löytyi, mutta kinkkukiusauksesta tuli kokeilun jälkeen yksi suosikkikotiruuistani! Ihmetyttää oikeastaan, että miksi edes lähdin ohjetta kokeilemaan, koska koulun ruokalan kinkkukiusaus on ollut ennemminki mulle inhotus, eikä mikään herkku. Nykyään meillä syödään kinkkukiusausta melkein joka viikko ja kaikki kenelle olen tätä tarjonnut, ovat kysyneet myös ohjetta, eli taitaa se maistua muillekin.
# Herkkukiusaus
# Tarvitset:
# 500g peruna-sipulisekoitusta
# 200g kinkkusuikaleita (tykkään niistä Korpelan kevyt kinkkusuikaleista, kun on tuollaisia "ohuita")
# 2dl ruokakermaa
# 100g tuorejuustoa oman maun mukaan (oma ehdoton suosikkini tähän on Creme Bonjour kreikkalainen valkosipuli!)
# 2rkl soijakastiketta
# 1rkl hunajaa
# juustoraastetta
# Tee näin:
# Laita peruna-sipulisekoitus ja kinkkusuikaleet kerroksittain voideltuun vuokaan. Sekoita ruokakermaan tuorejuusto, soijakastike ja hunaja. Kaada seos vuokaan. Ripottele juustoraastetta pinnalle. Kypsennä uunissa 200 asteessa noin tunti. Anna vetäytyä hetki ennen tarjoilua.
# That's it! Helppoa ja hyvää! Ohjetta voi sitten varioida esim. laittamalla kinkkusuikaleiden tilalle broileria jne...
# Kategoria:
# Ruokaa
# 1 kommentti
# Kommentoi
# Anna  kirjoitti 26.02.2010 - 09:18
# kuulostaapa hyvälle, pitää kokeilla joku kerta :)
# Nimesi
# Sähköpostiosoitteesi (ei näytetä yleisesti)
# Kotisivusi osoite
# Muista tietoni selaimen evästeessä seuraavia kommentointeja varten
# Seuraa tähän kirjoitukseen tulevia kommentteja
# (mikä tämä on? )
# Jos rastitat tämän kohdan kommentoinnin yhteydessä, saat sähköpostiisi tiedon kun muut käyttäjät lähettävät kommentteja tähän samaan kirjoitukseen ja pystyt helpommin seuraamaan keskustelua tästä kirjoituksesta. Voit koska tahansa peruuttaa tämän tilauksen napsauttamalla peruutuslinkkiä joka löytyy jokaisesta sähköpostiviestistä joka tulee tämän toiminnon perusteella. Jotta viestien lähetys onnistuu, tulee sinun jättää sähköpostiosoite kommentin yhteydessä. Sähköpostiosoite ei näy julkisesti, mutta näkyy blogin ylläpitäjälle.
# Kommentti
# Voit käyttää kommenteissasi seuraavia HTML-elementtejä: a, b, i, u, code
# Kirjoittaja
# Täällä höpöilee L, 25-vuotias pienen tytön äiti, joka tykkää mm. kakuista ja ruuasta ja ihanista esineistä ja omasta upouudesta omakotitalostaan ja sen sisustamisesta. Lisäksi käyttää paljon aikaa haaveiluun ja kaiken maailman suunnitelmiin, mutta tekee siitä huolimatta asiat yleensä vähän hetken mielijohteesta.
# Höpöhöpöily on sitä, kun on paljon asiaa, muttei kuitenkaan mitään asiaa!
# Kommentoikaa, kommentoikaa, kommentoikaa kaikki! :)
# Arkisto
# 2010
# </pre>

# %% [markdown]
# # CommonCrawl - try it yourself:
#
# * https://commoncrawl.org/the-data/get-started/
# * WARC files which store the raw crawl data
# * WAT files which store computed metadata for the data stored in the WARC
# * WET files which store extracted plaintext from the data stored in the WARC
#
# Let us try the WET files

# %%
# !wget  https://commoncrawl.s3.amazonaws.com/crawl-data/CC-MAIN-2021-04/wet.paths.gz
# Out:
# --2021-03-07 15:04:38--  https://commoncrawl.s3.amazonaws.com/crawl-data/CC-MAIN-2021-04/wet.paths.gz
# Resolving commoncrawl.s3.amazonaws.com (commoncrawl.s3.amazonaws.com)... 52.216.132.59
# Connecting to commoncrawl.s3.amazonaws.com (commoncrawl.s3.amazonaws.com)|52.216.132.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228621 (223K) [binary/octet-stream]
# Saving to: ‘wet.paths.gz’
#
# wet.paths.gz        100%[===================>] 223.26K  --.-KB/s    in 0.05s
#
# 2021-03-07 15:04:39 (3.98 MB/s) - ‘wet.paths.gz’ saved [228621/228621]

# %%
# !zcat wet.paths.gz | head -n 10
# !zcat wet.paths.gz | wc -l
# Out:
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00000.warc.wet.gz
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00001.warc.wet.gz
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00002.warc.wet.gz
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00003.warc.wet.gz
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00004.warc.wet.gz
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00005.warc.wet.gz
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00006.warc.wet.gz
# crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00007.warc.wet.gz
# ...

# %% [markdown]
# * There is almost 80,000 archives in the 01/2021 release of CommonCrawl
# * Let us pick the first one and see what is inside...

# %%
# %%bash
# one_archive=$(zcat wet.paths.gz | head -n 1)
# echo "Will download $one_archive"
# wget -nc --quiet https://commoncrawl.s3.amazonaws.com/$one_archive
# ls -hl *.wet.gz
# Out:
# Will download crawl-data/CC-MAIN-2021-04/segments/1610703495901.0/wet/CC-MAIN-20210115134101-20210115164101-00000.warc.wet.gz
# -rw-r--r-- 1 root root 149M Jan 28 18:58 CC-MAIN-20210115134101-20210115164101-00000.warc.wet.gz

# %%
# !zcat CC-MAIN-20210115134101-20210115164101-00000.warc.wet.gz | head -n 100
# Out:
# WARC/1.0
# WARC-Type: warcinfo
# WARC-Date: 2021-01-28T18:45:57Z
# WARC-Filename: CC-MAIN-20210115134101-20210115164101-00000.warc.wet.gz
# WARC-Record-ID: <urn:uuid:c8e974fb-bbb9-4ff9-ba62-c448866593b0>
# Content-Type: application/warc-fields
# Content-Length: 372
#
# Software-Info: ia-web-commons.1.1.10-SNAPSHOT-20210112092133
# Extracted-Date: Thu, 28 Jan 2021 18:45:57 GMT
# robots: checked via crawler-commons 1.2-SNAPSHOT (https://github.com/crawler-commons/crawler-commons)
# isPartOf: CC-MAIN-2021-04
# operator: Common Crawl Admin (info@commoncrawl.org)
# description: Wide crawl of the web for January 2021
# publisher: Common Crawl
#
#
#
# WARC/1.0
# WARC-Type: conversion
# WARC-Target-URI: http://03fotos.com/03magazine/2017/07/22/%E3%80%8E%E3%81%82%E3%82%8A%E3%81%8C%E3%81%A8%E3%81%86%E3%80%81%E3%83%88%E3%83%8B%E3%83%BB%E3%82%A8%E3%83%AB%E3%83%89%E3%83%9E%E3%83%B3%E3%80%8F/
# WARC-Date: 2021-01-15T15:26:09Z
# WARC-Record-ID: <urn:uuid:f1d4b983-02cb-4b0c-9310-d5c8901bf41a>
# ...

# %% [markdown]
# # Inspect the archive
#
# * e.g. the warc python library can be used

# %%
# !pip install warc3-wet

# %%
import itertools
import warc
with warc.open("CC-MAIN-20210115134101-20210115164101-00000.warc.wet.gz","rb") as f:
    for record in itertools.islice(f,10000):
        text=record.payload.read().decode("utf-8")
        if "warc-identified-content-language" not in record.header:
            continue
        lang=record["warc-identified-content-language"]
        langs=lang.split(",")
        if "fin" in langs:
            print(langs,record.header["WARC-Target-URI"],text[:200].replace("\n"," "))
# Out:
# ['eng', 'fin'] http://annikagrof.com/works-section/ Annika Grof - works section Annika Grof home works about now contact home works about now contact works section Full CV (pdf) show all commercial documentary drama entertainment Syksyn jälkeen saapuu
# ['fin'] http://bbstat.kapsi.fi/index.php?bblang=fi&option=com_bbstat&task=game_detail&id=7540&game_sort=points&game_dir=DESC&game_extra_sort=points&game_extra_dir=DESC&playerstat_sort=points&playerstat_dir=DESC&view_mode=list&games_sort=points_1p&games_dir=DESC&games_sort1_mode=norm bbStat - Ottelu / BC Sisu - Bunch-80 Uutiset Tilastot Pelaajat Sarjat Seurat Joukkueet Sivuston toiminnassa voi esiintyä tällä hetkellä paikoin vakaviakin ongelmia johtuen ohjelmistojen päivityksestä.
# ['fin', 'eng'] http://finto.fi/yso/fi/page/p1310 Finto: YSO: energia Hyppää sisältöön Finto | på svenska in English Sanastot Tietoja Palaute Ohje YSO - Yleinen suomalainen ontologia Hae sanastosta Sisällön kieli Sisällön ja haun kieli suomi englanti
# ...

# %% [markdown]
# * What can we say about the CommonCrawl data?

# %% [markdown]
# ## Full archive of Suomi24.fi discussions
#
# * Yay! Who wouldn't want that kind of stuff!
# * Download from kielipankki.fi
# * Unfortunately it is a monstrous zip file, we have no hope to process it in Google Colab
# * Can be used for research purposes

# %% [markdown]
# ## Finnish Internet Parsebank
#
# * About 3.7 billion tokens (words and punctuation) of Finnish crawled on the Internet
# * Can be used for research purposes upon request
#
# ```
# ###C:DUPLICATION_RATE:0.0
# ###C:<doc id="2-125008" length="1k-10k" crawl_date="2014-06-24" url="http://www.elamyksentaika.fi/tap_krapi.html" langdiff="0.33">
# ###C:START_TEXT_BLOCK:1008205
# 1       Krapi   Krapi   PROPN   _       Case=Nom|Number=Sing    0       root    _       _
#
# ###C:START_TEXT_BLOCK:1008206
# 1       Tuusulanjärven  Tuusulanjärven  PROPN   _       Case=Gen|Number=Sing    2       nmod:poss       _       _
# 2       kulttuurimaiseman       kulttuuri#maisema       NOUN    _       Case=Gen|Number=Sing    3       nmod:poss       _       _
# 3       ytimessä        ydin    NOUN    _       Case=Ine|Number=Sing    4       nmod    _       _
# 4       sijaitseva      sijaita VERB    _       Case=Nom|Degree=Pos|Number=Sing|PartForm=Pres|VerbForm=Part|Voice=Act   8       acl     10:acl  _
# 5       perinteikäs     perinteikäs     ADJ     _       Case=Nom|Degree=Pos|Number=Sing 8       amod    _       _
# 6       ja      ja      CONJ    _       _       5       cc      _       _
# 7       palveleva       palvella        VERB    _       Case=Nom|Degree=Pos|Number=Sing|PartForm=Pres|VerbForm=Part|Voice=Act   5       conj    8:acl   _
# 8       hotelli-        hotelli NOUN    _       Case=Nom|Number=Sing    11      nsubj   _       _
# 9       ja      ja      CONJ    _       _       8       cc      _       _
# 10      ravintolakokonaisuus    ravintola#kokonaisuus   NOUN    _       Case=Nom|Number=Sing    8       conj    11:nsubj        _
# 11      tarjoaa tarjota VERB    _       Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act 0       root    _       _
# 12      ryhmällesi      ryhmä   NOUN    _       Case=All|Number=Sing|Number[psor]=Sing|Person[psor]=2   11      nmod    _       _
# 13      upeat   upea    ADJ     _       Case=Nom|Degree=Pos|Number=Plur 14      amod    _       _
# 14      puitteet        puite   NOUN    _       Case=Nom|Number=Plur    11      dobj    _       _
# 15      tapahtumien     tapahtuma       NOUN    _       Case=Gen|Number=Plur    16      nmod:gobj       _       _
# 16      järjestämiseen  järjestää       NOUN    _       Case=Ill|Derivation=Minen|Number=Sing   11      nmod    _       _
# 17      ympäri  ympäri  ADP     _       AdpType=Prep    18      case    _       _
# 18      vuoden  vuosi   NOUN    _       Case=Gen|Number=Sing    16      nmod    _       _
# 19      .       .       PUNCT   _       _       11      punct   _       _
#
# 1       Täyden  täysi   ADJ     _       Case=Gen|Degree=Pos|Number=Sing 2       amod    _       _
# 2       palvelun        palvelu NOUN    _       Case=Gen|Number=Sing    3       nmod:poss       _       _
# 3       paikasta        paikka  NOUN    _       Case=Ela|Number=Sing    4       nmod    _       _
# 4       löydät  löytää  VERB    _       Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act 0       root    _       _
# 5       kaikki  kaikki  PRON    _       Case=Nom|Number=Sing|PronType=Ind       7       det     _       _
# 6       tasokkaat       tasokas ADJ     _       Case=Nom|Degree=Pos|Number=Plur 7       amod    _       _
# 7       palvelut        palvelu NOUN    _       Case=Nom|Number=Plur    4       dobj    _       _
# 8       :       :       PUNCT   _       _       9       punct   _       _
# 9       ravintolat      ravintola       NOUN    _       Case=Nom|Number=Plur    7       appos   _       _
# 10      ,       ,       PUNCT   _       _       7       punct   _       _
# 11      saunat  sauna   NOUN    _       Case=Nom|Number=Plur    7       conj    4:dobj  _
# 12      ,       ,       PUNCT   _       _       7       punct   _       _
# 13      hotelli hotelli NOUN    _       Case=Nom|Number=Sing    7       conj    4:dobj  _
# 14      sekä    sekä    CONJ    _       _       7       cc      _       _
# 15      ohjelmapalvelut ohjelma#palvelu NOUN    _       Case=Nom|Number=Plur    7       conj    4:dobj  _
# 16      .       .       PUNCT   _       _       4       punct   _       _
#
# ###C:START_TEXT_BLOCK:1008207
# 1       Suuri   suuri   ADJ     _       Case=Nom|Degree=Pos|Number=Sing 4       amod    _       _
# 2       ja      ja      CONJ    _       _       1       cc      _       _
# 3       puistomainen    puisto#mainen   ADJ     _       Case=Nom|Degree=Pos|Number=Sing 1       conj    4:amod  _
# 4       piha-alue       piha-alue       NOUN    _       Case=Nom|Number=Sing    5       nsubj   _       _
# 5       mahdollistaa    mahdollistaa    VERB    _       Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act 0       root    _       _
# 6       suurenkin       suu#re  NOUN    _       Case=Gen|Clitic=Kin|Number=Sing 7       nmod:poss       _       _
# 7       ryhmän  ryhmä   NOUN    _       Case=Gen|Number=Sing    9       nmod:poss       _       _
# 8       aktiivisen      aktiivinen      ADJ     _       Case=Gen|Degree=Pos|Number=Sing 9       amod    _       _
# 9       päivän  päivä   NOUN    _       Case=Gen|Number=Sing    5       dobj    _       _
# 10      .       .       PUNCT   _       _       5       punct   _       _
#
# 1       Tuusulan        Tuusula PROPN   _       Case=Gen|Number=Sing    3       nmod:poss       _       _
# 2       maineikas       maineikas       ADJ     _       Case=Nom|Degree=Pos|Number=Sing 3       amod    _       _
# 3       Rantatie        ranta#tie       NOUN    _       Case=Nom|Number=Sing    4       nsubj   _       _
# 4       lähtee  lähteä  VERB    _       Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act 0       root    _       _
# 5       aivan   aivan   ADV     _       _       6       advmod  _       _
# 6       Krapin  Krapi   PROPN   _       Case=Gen|Number=Sing    7       nmod:poss       _       _
# 7       pihasta piha    NOUN    _       Case=Ela|Number=Sing    4       nmod    _       _
# 8       .       .       PUNCT   _       _       4       punct   _       _
# ```

# %% [markdown]
# ## Wikipedia
#
# * https://dumps.wikimedia.org/
# * Dumps of wikipedia data
# * Nearly 80 million words in the Finnish Wikipedia (early 2019), billions of words for English
#
# ```
# <mediawiki xmlns="http://www.mediawiki.org/xml/export-0.10/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd" version="0.10" xml:lang="fi">
#   <siteinfo>
#     <sitename>Wikipedia</sitename>
#     <dbname>fiwiki</dbname>
#     <base>https://fi.wikipedia.org/wiki/Wikipedia:Etusivu</base>
#     <generator>MediaWiki 1.27.0-wmf.10</generator>
#     <case>first-letter</case>
#     <namespaces>
#       <namespace key="-2" case="first-letter">Media</namespace>
#       <namespace key="-1" case="first-letter">Toiminnot</namespace>
#       <namespace key="0" case="first-letter" />
#       <namespace key="1" case="first-letter">Keskustelu</namespace>
#       <namespace key="2" case="first-letter">Käyttäjä</namespace>
#       <namespace key="3" case="first-letter">Keskustelu käyttäjästä</namespace>
#       <namespace key="4" case="first-letter">Wikipedia</namespace>
#       <namespace key="5" case="first-letter">Keskustelu Wikipediasta</namespace>
#       <namespace key="6" case="first-letter">Tiedosto</namespace>
#       <namespace key="7" case="first-letter">Keskustelu tiedostosta</namespace>
#       <namespace key="8" case="first-letter">Järjestelmäviesti</namespace>
#       <namespace key="9" case="first-letter">Keskustelu järjestelmäviestistä</namespace>
#       <namespace key="10" case="first-letter">Malline</namespace>
#       <namespace key="11" case="first-letter">Keskustelu mallineesta</namespace>
#       <namespace key="12" case="first-letter">Ohje</namespace>
#       <namespace key="13" case="first-letter">Keskustelu ohjeesta</namespace>
#       <namespace key="14" case="first-letter">Luokka</namespace>
#       <namespace key="15" case="first-letter">Keskustelu luokasta</namespace>
#       <namespace key="100" case="first-letter">Teemasivu</namespace>
#       <namespace key="101" case="first-letter">Keskustelu teemasivusta</namespace>
#       <namespace key="102" case="first-letter">Metasivu</namespace>
#       <namespace key="103" case="first-letter">Keskustelu metasivusta</namespace>
#       <namespace key="104" case="first-letter">Kirja</namespace>
#       <namespace key="105" case="first-letter">Keskustelu kirjasta</namespace>
#       <namespace key="828" case="first-letter">Moduuli</namespace>
#       <namespace key="829" case="first-letter">Keskustelu moduulista</namespace>
#       <namespace key="2300" case="first-letter">Gadget</namespace>
#       <namespace key="2301" case="first-letter">Gadget talk</namespace>
#       <namespace key="2302" case="case-sensitive">Gadget definition</namespace>
#       <namespace key="2303" case="case-sensitive">Gadget definition talk</namespace>
#       <namespace key="2600" case="first-letter">Aihe</namespace>
#     </namespaces>
#   </siteinfo>
#   <page>
#     <title>Amsterdam</title>
#     <ns>0</ns>
#     <id>1</id>
#     <revision>
#       <id>15069537</id>
#       <parentid>15069530</parentid>
#       <timestamp>2015-07-15T05:23:44Z</timestamp>
#       <contributor>
#         <username>Htm</username>
#         <id>60444</id>
#       </contributor>
#       <minor />
#       <comment>/* Monumentteja ja rakennuksia */ lähdeviite fix</comment>
#       <model>wikitext</model>
#       <format>text/x-wiki</format>
#       <text xml:space="preserve">{{Kaupunki2
# | virallinen_nimi = Amsterdam
# | muu_nimi =
# | alkuperäinen_nimi = &lt;!-- kaupungeille, joiden alkuperäinen nimi ei ole suomenkielinen --&gt;
# | lempinimi =
# | motto  =
# | kuva_taivaanranta = AmsterdamMontage.jpg
# | kuvakoko =
# | kuvateksti =
# | kuva_lippu = Flag of Amsterdam.svg
# | lippu_koko =
# | kuva_vaakuna = Wapen van Amsterdam bewerkt.PNG
# | vaakuna_koko =
# | kilpi_koko =
# | kaupungin_logo =
# | kaupungin_logon_koko =
# | kuva_kartta = LocatieAmsterdam.svg
# | kartta_koko =
# | kartta_kuvateksti =
# | pushpin_map = &lt;!-- the name of a location map as per http://fi.wikipedia.org/wiki/Malline:Location_map --&gt;
# | pushpin_label_position = &lt;!-- the position of the pushpin label: left, right, top, bottom, none --&gt;
# | aluetyyppi = &lt;!--esimerkiksi Valtio--&gt;
# | alueen_nimi = &lt;!--Valtion nimi--&gt;
# | aluetyyppi1 = [[Alankomaiden provinssit|Provinssi]]
# | alueen_nimi1 = [[Pohjois-Hollanti]]
# | aluetyyppi2 =
# | alueen_nimi2 =
# | aluetyyppi3 =
# | alueen_nimi3 =
# | aluetyyppi4 =
# | alueen_nimi4 =
# | hallinnon_tyyppi =
# | johtajan_arvonimi = Pormestari
# | johtajan_nimi = [[Eberhard van der Laan]]
# | johtajan_arvonimi1 = &lt;!-- paikoille, joissa useampi, esimerkiksi pormestari ja kaupunginjohtaja --&gt;
# | johtajan_nimi1 =
# | johtajan_arvonimi2 =
# | johtajan_nimi2 =
# | johtajan_arvonimi3 =
# | johtajan_nimi3 =
# | johtajan_arvonimi4 =
# | johtajan_nimi4 =
# | perustettu_nimeke = &lt;!-- esimerkiksi Perustettu --&gt;
# | perustettu_päivämäärä =
# | perustettu_nimeke2 = &lt;!-- Incorporated (town) --&gt;
# | perustettu_päivämäärä2 =
# | perustettu_nimeke3 = &lt;!-- Incorporated (city) --&gt;
# | perustettu_päivämäärä3 =
# | pinta-ala_huom =
# | pinta-ala_yhteensä = 219,07
# | pinta-ala_maa = 166
# | pinta-ala_vesi = 53
# | pinta-ala_veden_osuus% =
# | pinta-ala_metro = 1 815
# | väkiluku_vuosi = 2006
# | väkiluku_huom =
# | asutustyyppi = &lt;!--kylälle tai pienemmälle asutukselle (kaupungin ollessa kyseessä jätä tyhjäksi)--&gt;
# | väkiluku_yhteensä = 741 329
# | väestötiheys = 4 431
# | väkiluku_metropoli = 1 450 000
# | väestötiheys_metro =
# | utc_ero = +1
# | utc_ero_kesäaika = +2
# | latd  = 52
# | latm  = 22
# | lats  =
# | latNS  = N
# | longd  = 4
# | longm  = 54
# | longs  =
# | longEW  = E
# | korkeus_merenpinnasta = 2
# | postinumero_tyyppi = Postinumero
# | postinumero = 1011–1109
# | suuntanumero = 020
# | kotisivu = [http://www.amsterdam.nl/ www.amsterdam.nl]
# | huomautukset =
# }}
#
# '''Amsterdam''' on [[Alankomaat|Alankomaiden]] [[pääkaupunki]]. Amsterdam on väkiluvultaan [[Luettelo Alankomaiden suurimmista kaupungeista|Alankomaiden suurin kaupunki]], huhtikuun alussa 2006 siellä asui 743&amp;nbsp;905 asukasta eli noin joka 20. hollantilainen asuu varsinaisessa Amsterdamissa. Yhteensä Amsterdamissa ja sitä ympäröivällä kaupunkialueella asuu noin 1&amp;nbsp;450&amp;nbsp;000 ihmistä eli vajaa kymmenesosa Alankomaiden asukkaista. Amsterdam sijaitsee Amstelin suistossa [[IJsselmeer]]in rannalla Alankomaiden [[Pohjois-Hollanti|Pohjois-Hollannin]] provinssissa. Vaikka Amsterdam on Alankomaiden perustuslain mukaan maan pääkaupunki, sijaitsee niin kuningashuone, hallitus, parlamentti kuin korkein oikeuskin [[Haag]]issa.
#
# == Historia ==
#
# Amsterdamin paikalle rakennettiin ensimmäiset puutalot 1200-luvun alkupuolella. Kaupunki linnoitettiin suojaksi vihollisilta; [[Amstel|Amstel-joki]] padottiin nykyisen Damin aukion kohdalta. Padon avulla pystyttiin säätelemään veden korkeuden lisäksi myös kauppaa, sillä se esti merikelpoisia aluksia purjehtimasta yläjuoksulle. Siksi rahti jouduttiinkin siirtämään paikallisiin aluksiin jatkokuljetusta varten. Näin asukkaat saivat tästä koituneet tulot itselleen.
# Vuonna 1275 Amsterdam sai Hollannin kreiviltä oikeuden kuljettaa rahtia Amstel-joella ilman tulleja, ja sen seurauksena kyseisen joen kauppa monopolisoitui. Amsterdamin mahti kaupankäynnissä vain kasvoi, kun se pystyi viemään yhä useampaa tuotetta muualle [[Eurooppa]]an vapaasti, esimerkiksi olutta.
#
# Kauppa laajeni ja 1300- ja 1400-luvulla kaupungin asukasluku kasvoi nopeasti. Se kuitenkin kärsi tuhoisista tulipaloista vuosina 1421 ja 1452, jotka hävittivät suuren osan kaupunkia. Sen seurauksena puurakentaminen kiellettiin ja ensisijaiseksi rakennusmateriaaliksi tuli tiili.
# 1400-luvulla hallitsijasukujen väliset avioliitot johtivat siihen, että valtaan tuli maassa [[Espanja]]n [[Kaarle V (keisari)|Kaarle V]], joka hallitsi myös [[Itävalta]]a. Espanjan hallinta-aika oli erittäin julmaa. Tärkeänä kauppasatamana Amsterdam kuitenkin säästyi pahimmalta sorrolta ja väkivallalta. Sen väkiluku kolminkertaistui, kun sinne muutti pakolaisia muualta valtakunnasta, myös [[juutalaisuus|juutalaisia]] [[Portugali]]sta.
# [[Jean Calvin]]in oppien juurruttua maahan Espanja alkoi kurittaa [[harhaoppisuus|harhaoppisia]]. Damin aukiolla taas järjestettiin paavin vastaisia mielenosoituksia. [[katolisuus|Katoliset]] Espanjan johtajat kielsivät lopulta [[kalvinismi]]n ja [[protestanttisuus|protestanttien]] vainoaminen jatkui.
# Vuonna 1578 amsterdamilaiset ryhtyivät kapinaan ja häätivät paavin kannattajat pois kaupungista. Katolisia kirkkoja hävitettiin ja katolisia käännytettiin protestanteiksi.
# [[Kuva:Cornelis anthonisz vogelvluchtkaart amsterdam.JPG|thumb|left|Maalaus Amsterdamista vuonna 1538.]]
#
# Espanjan vallan loputtua Amsterdamissa alkoivat paremmat ajat. Kaupankäynti laajentui jatkuvasti ja siitä seurannutta kukoistusaikaa kutsutaan Alankomaiden kulta-ajaksi. Amsterdamin elinkeinoelämän mahdollisuudet houkuttelivat kaupunkiin paljon uusia asukkaita. Vanha keskiaikainen kaupunki jäi liian pieneksi ja uusia kanavia alettiin rakentaa. 1600-luvulla kaupungin reunamille muodostui kolmen kanavan Kanavakehä (''Grachtengordel''), joka on vuodesta 2010 ollut [[UNESCO:n maailmanperintöluettelo]]ssa. Kanavat Herengraht, Keizersgracht ja Prinsengracht rakentuivat täyteen toinen toistaan komeampia päätykolmiotaloja.&lt;ref name=&quot;top10&quot; /&gt; Vauraus johti myös taiteen ja luonnontieteen kehitykseen. [[Rembrandt]], [[Frans Hals]], [[Johannes Vermeer|Vermeer]] ja [[Paulus Potter]] vaikuttivat siihen aikaan, ja heidän työnsä olivat erittäin kysyttyjä vauraamman väestönosan keskuudessa.
#
# 1700-luvulla Amsterdamista tuli maailman suurin pankkikeskus, mutta kulta-aika oli loppumassa. [[Yhdistynyt kuningaskunta|Ison-Britannian]] tuhottua maan laivaston sodassa vuonna 1780, alkoi todellinen rappio. Myös [[Hollannin Itä-Intian kauppakomppania|Yhdistynyt Itä-Intian kauppakomppania]](VOC) teki vararikon vuonna 1791. Neljä vuotta myöhemmin [[Napoleon I|Napoleon]] valloitti maan ja se oli taas vieraan vallassa.
# [[Kuva:Prinsengrachtskaalattu.JPG|thumb|left|200px|Prinsengrachtin kanava nähtynä [[Westerkerk]]in tornista.]]
# 1800-luvulla tilanne Amsterdamissa parani, kun Ranskan valta oli alkanut heiketä. Vuosisadan loppupuolella Amsterdamiin perustettiin suuria puistoja ja museoita, ja elintaso kohosi huomattavasti.
#
# Alankomaat pysyi [[Ensimmäinen maailmansota|ensimmäisen maailmansodan]] puolueettomana. 1900-luvun alussa ponnistelut keskittyivät lähinnä maankuivaukseen, jolla pyrittiin lisäämään maataloutta ja elintilaa. [[Toinen maailmansota|Toisessa maailmansodassa]] maa kuitenkin vallattiin vuonna 1940 ja Amsterdamin juutalaisia vietiin keskitysleireihin, joista he eivät ikinä palanneet. Väestö alkoi nähdä nälkää, kun elintarvikkeiden ja polttoaineen jakelu lopetettiin. Maa vapautettiin vasta vuonna 1945.
#
# Toisen maailmansodan jälkeen Amsterdamin suvaitsevaisuus houkutteli paljon hippejä ja muita vaihtoehtokulttuurien edustajia. Kun kaupungin vanhoja rakennuksia oltiin purkamassa, aiheutti tämä suuren vastalausemyrskyn. Näin ollen esimerkiksi Jordaanin alue säästyi. Sittemmin Amsterdamista on kehittynyt yksi maailman suosituimmista kaupunkimatkakohteista, johtuen varmasti historiallisesta keskustasta ja ainutlaatuisesta taidehistoriasta. Nykypäivänä amsterdamilaisten huolenaiheena on ilmaston lämpenemisestä johtuva vedenpinnan nousu, joka uhkaa nousta kriittiselle tasolle. Alankomaissa on tehtävä paljon töitä sen eteen.
#
# == Maantiede ja ilmasto ==
#
# Amsterdamissa vallitsee lauhkea [[meri-ilmasto]]. Sen läheisyys [[Pohjanmeri|Pohjanmereen]] vaikuttaa voimakkaasti säätiloihin. Talvet ovat leutoja, lämpötila laskee yhä harvemmin pakkasen puolelle.{{Kenen mukaan}} Kesät ovat yleensä lämpimiä, harvoin kuumia. Syksyt ovat sateisia.
#
# {{Ilmastotaulukko
# | Taulukko =
# | Lämpötilataulukko =
# | Sadantataulukko =
# | Sadantataulukon korkeus = 200
# | Sijainti genetiivissä = Amsterdamin
# | Lähde = {{Verkkoviite | Osoite = http://www.worldweather.org/037/c00143.htm | Nimeke = Weather Information for Amsterdam | Julkaisu = World Weather Information Service | Julkaisija = World Meteorological Organization | Viitattu = 21.1.2010 }}
# | Otsikko  =
# | kltammi  = 5.4
# | klhelmi  = 6.0
# | klmaalis = 9.2
# | klhuhti  = 12.4
# | kltouko  = 17.1
# | klkesä   = 19.2
# | klheinä  = 21.4
# | klelo    = 21.8
# | klsyys   = 18.4
# | klloka   = 14.1
# | klmarras = 9.2
# | kljoulu  = 6.5
# | mltammi  = 0.5
# | mlhelmi  = 0.2
# | mlmaalis = 2.4
# | mlhuhti  = 4.0
# | mltouko  = 7.8
# | mlkesä   = 10.4
# | mlheinä  = 12.5
# | mlelo    = 12.3
# | mlsyys   = 10.2
# | mlloka   = 7.0
# | mlmarras = 3.9
# | mljoulu  = 1.9
# | ketammi  =
# | kehelmi  =
# | kemaalis =
# | kehuhti  =
# | ketouko  =
# | kekesä   =
# | keheinä  =
# | keelo    =
# | kesyys   =
# | keloka   =
# | kemarras =
# | kejoulu  =
# | satammi  = 62
# | sahelmi  = 43
# | samaalis = 59
# | sahuhti  = 41
# | satouko  = 58
# | sakesä   = 68
# | saheinä  = 66
# | saelo    = 61
# | sasyys   = 82
# | saloka   = 85
# | samarras = 89
# | sajoulu  = 75
# | pptammi  =
# | pphelmi  =
# | ppmaalis =
# | pphuhti  =
# | pptouko  =
# | ppkesä   =
# | ppheinä  =
# | ppelo    =
# | ppsyys   =
# | pploka   =
# | ppmarras =
# | ppjoulu  =
# | vltammi  =
# | vlhelmi  =
# | vlmaalis =
# | vlhuhti  =
# | vltouko  =
# | vlkesä   =
# | vlheinä  =
# | vlelo    =
# | vlsyys   =
# | vlloka   =
# | vlmarras =
# | vljoulu  =
# | sptammi  = 17
# | sphelmi  = 13
# | spmaalis = 17
# | sphuhti  = 14
# | sptouko  = 14
# | spkesä   = 14
# | spheinä  = 13
# | spelo    = 13
# | spsyys   = 16
# | sploka   = 17
# | spmarras = 19
# | spjoulu  = 18
# }}
#
# == Kulttuuri ==
#
# Amsterdam on pienuudestaan huolimatta merkittävä kulttuurikaupunki. Arkkitehtuuri on kaupungissa ainutlaatuista kanaalien hallitessa kaupunkikuvaa. Kaupungissa on useita merkittäviä museoita, muun muassa useita [[Rembrandt]]in töitä sisältävä valtionmuseo [[Rijksmuseum]], [[Vincent van Gogh]]in tuotantoon keskittyvä [[Van Gogh Museum]] sekä juutalaisvainojen ajoista kertova [[Anne Frankin talo]].
#
# Kaupungissa toimii yksi maailman kuuluisimmista orkestereista, [[Concertgebouw-orkesteri]], joka esiintyy [[Museumplein]]in kupeessa sijaitsevassa [[Concertgebouw|Concertgebouw-konserttitalossa]]. [[Bimhuis]] (lähellä keskusrautatieasemaa) keskittyy jazz- sekä improvisoituun musiikkiin. [[Leidseplein]] on yksi yöelämän keskuksista, ja sen ympäristössä sijaitsevat [[Melkweg]] ja [[Paradiso]] ovat areenoita monien eri alojen esiintyjille.
#
# Kaupunki on kuuluisa monia vuosisatoja vanhasta suvaitsevaisuuden perinteestä ja siitä onkin muodostunut eurooppalaisen vapaamielisyyden vertauskuva. Prostituutio on laillista, ja [[punaisten lyhtyjen alue]]&lt;ref&gt;{{k-en|Red Light District}}, äännetään [[kansainvälinen foneettinen aakkosto|IPAn]] mukaan [red lait distrikt]&lt;br /&gt;{{Kirjaviite | Tekijä= Raija Hurme, Maritta Pesonen ja Olli Syväoja | Nimike= Englanti–suomi suursanakirja. English–Finnish General Dictionary | Julkaisija= [[WSOY]] ja [[Valitut Palat]] | Vuosi= [[1995]] | Tunniste= ISBN 951-584-128-3}}&lt;/ref&gt; ({{k-nl|De wallen}}), [[kannabis]]tuotteita myyvät [[coffee shop]]it ja monipuolinen yöelämä (baareja ja kahviloita yhteensä noin 1500) houkuttelevat runsaasti turisteja. Alankomaat ovat kuitenkin päättäneet rajoittaa kannabiksen käyttöä kahviloiden ottaessa käyttöön ns. klubikortit, joita voidaan myöntää vain täysi-ikäisille hollantilaisille.&lt;ref name=&quot;klubikortit&quot;&gt;{{Verkkoviite | Osoite=http://www.findance.com/uutiset/15422/amsterdam-stoppi-turistien-marihuanan-kaytolle | Nimeke=Amsterdam: stoppi turistien marihuanan käytölle| Tekijä=Findance.com | Viitattu=17. kesäkuuta 2011}}&lt;/ref&gt; Provinssit saavat itsenäisesti päättää rajoittavatko myyntiä vain paikallisille eikä lakia ole otettu käyttöön Amsterdamissa.&lt;ref&gt;{{Verkkoviite | Osoite = http://www.amsterdamtourist.info/things-to-do-in-amsterdam/amsterdam-coffeeshops/| Nimeke = What about the Coffeeshops in Amsterdam? | AmsterdamTourtist.info| Tekijä = | Julkaisu =AmsterdamTourist.info| Ajankohta = | Viitattu = 25.6.2015}}&lt;/ref&gt;
#
# == Nähtävyydet ==
# [[Kuva:Koninklijk paleiswiki.JPG|thumb|220px|Koninklijk Paleis Dam-aukiolla]]
#
# === Kaupunginosat ja alueet ===
#
# * Kanavakehä (Grachtengodel)
# * [[Jordaan]]
# * [[Leidseplein]]
# * [[De Wallen]] ([[Punaisten lyhtyjen alue]])
# * [[Rembrandtplein]]
# * [[Amsterdam-Noord]]
# * [[Bos_en_lommer|Bos en Lommer]]
# * [[De_Baarsjes|De Baarsjes]]
#
# === Kirkkoja (katolisia ja protestanttisia)===
# [[Kuva:Amsterdam red light district 24-7-2003.JPG|thumb|220px|Punaisten lyhtyjen alue]]
# * [[Nieuwe Kerk (Amsterdam)|Nieuwe Kerk]]
# * [[Oude Kerk]]
# * [[Westerkerk]]
# * [[Zuiderkerk]]
# * ''Noorderkerk'', jonka edessä on vuonna 1934 tapahtuneiden ''Jordaanoproer''-mellakoiden uhrien muistopatsas&lt;ref name=&quot;top10&quot; /&gt;
#
# === Monumentteja ja rakennuksia ===
# [[Tiedosto:Reguliersdwarsstraat 15.JPG|thumb|Talon pääty, vinssi ja koukku. Reguliersdwarsstraat 15]]
# Amsterdamin maaperä on huokoista suota. Kovaa hiekkamaata on vasta noin 13 metrin syvyydessä. 1600-luvulta alkaen talot tuettiin paaluttamalla niiden perustukset hiekkamaahan asti. Osa näistä puisista paaluista on mädäntynyt, jolloin talo saattaa vähitellen vajota. Turistikin havaitsee, että vanhat talot voivat olla hiukan vinossa. Vinouden syyksi on esitetty myös tahallista vinoon rakentamista, sillä kanavaan päin kaltevaan taloon voitiin nostaa tavaraa vinssillä helpommin. Tähän viittaa se, että vuonna 1565 määrättiin, että talojen kaltevuus saa olla enintään 1:25.&lt;ref name=&quot;berl&quot;&gt;{{Kirjaviite | Nimeke = Berlitz Amsterdam Pocket Guide| Julkaisija = Tammi| Vuosi = 2005| Tekijä = Bennet, Lindsey| Suomentaja = Katri Mäkinen, Saara Toivonen| Sivut = 27, 49| Isbn = 951-31-3345-7}}&lt;/ref&gt;
#
# 1600-luvun taloissa on varsin yhtenäinen rakennustyyli. Taloja verotettiin niiden viemän katutilan mukaan, joten niiden kadunpuoleinen sivu tehtiin lyhyeksi (8-10 metriä) ja pääty on kadulle päin. Päätykolmioita on erilaisia: perusratkaisuina ovat yksinkertainen kolmiopääty, kellomainen pääty, tornimainen pääty, varastojen harjakattopääty ja porraspääty. Päätyyn kuuluu lähes aina tavaroiden nostamiseen tarkoitettu vinssi ja siihen kuuluva koukku.&lt;ref name=&quot;berl&quot; /&gt;
#
# Merkittäviä rakennuksia ja monumentteja:
# * ''Koninklijk Paleis'', kuninkaanlinna
# * ''Schreierstoren'', kyyneltentorni, joka on kaupunginmuurin säilynyt osa
# * tuulimylly ''De Gooyer''
# * ''Trippenhuis'', asekauppiassuvun talo
# * Tiede- ja tekniikkakeskus NEMO, joka esittelee tieteen saavutuksia maallikoille&lt;ref name=&quot;berl&quot; /&gt;
# * ''Homomonument'', joka on maailman ensimmäinen homoseksuaaleille omistettu muistomerkki, pystytetty toisen maailmansodan homoseksuaalivainojen muistoksi&lt;ref name=&quot;top10&quot;&gt;{{Kirjaviite | Nimeke = Top 10 Amsterdam| Julkaisija = WSOY| Vuosi = 2013 | Tekijä = Duncan, Fiona &amp; Glass, Leonie| Suomentaja = Welling-Hirvonen, Sari | Sivut = 8-9, 44-45, 90-93| Isbn = 978-951-0-39477-9}}&lt;/ref&gt;
# ```

# %% [markdown]
# # Pre-extracted Wikipedia
#
# * Any number of tools exist to extract text from the raw Wikipedia dumps
# * Wikidump files are massive, CPU-intensive processing
# * Pre-extracted wiki corpora exist, e.g. here:
#
# https://linguatools.org/tools/corpora/wikipedia-monolingual-corpora/

# %% [markdown]
# # CoNLL 2018 raw texts
# * https://lindat.mff.cuni.cz/repository/xmlui/handle/11234/1-1989
# * Texts prepared for CoNLL Shared Task 2018 (http://universaldependencies.org/conll18/)
# * 45 different languages, 90 billion words in total

# %% [markdown]
# ## Medical research articles
#
# * Millions of full text research articles http://www.ncbi.nlm.nih.gov/pmc/tools/openftlist/
# * 30+ milion research article abstracts http://www.ncbi.nlm.nih.gov/pubmed

# %% [markdown]
# # Legality of this all
#
# * Finnish copyright law highly restrictive
# * No "fair use" despite popular belief
# * Before you go ahead and start making money by your new text mining skills, do talk to a lawyer
# * Personal use for own purposes seems to be okay in the opinion of many (this is not a legal advice)
