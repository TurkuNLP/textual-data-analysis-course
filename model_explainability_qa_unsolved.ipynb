# %% [markdown]
# <a href="https://colab.research.google.com/github/TurkuNLP/textual-data-analysis-course/blob/main/model_explainability_qa_unsolved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1
#
# On the lecture, I showed how Integrated Gradients can pinpoint the answer to a question for the yes/no classification QA model. I repeat this result below.
#
# Your task will be to replicate this result. I.e. pick the QA classification model from exercise 4.2 (solutions are linked in Moodle) and explain the prediction with the Integrated Gradients method. This is not difficult to achieve, but needs some extra care:
#
# 1. The code to load the trained QA classification model you can find in the notebook solving exerise 4.2
# 2. The code for basic explanation with IG you can find in this week's lecture
# 3. You need to combine these two and modify the IG code so as to work with question-answer pairs (calls to the tokenizer are affected, and the generation of the blank IG reference input is affected as well) You may also stop to think what the blank example should look like. All PAD? Or maybe just the answer part?

# %%
# !pip3 install transformers

# %%
# !wget http://dl.turkunlp.org/TKO_8964_2023/english-binarized-weighted.model.tgz
# !tar zxvf english-binarized-weighted.model.tgz

# %%
# relevant stuff repeated from above so you can run it from here onwards if you happen to have the model trained

from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from transformers import TrainingArguments
from transformers import Trainer

MODEL_NAME = 'english-binarized-weighted.model'

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %% [markdown]
# ....all your code goes here...

# %%
import captum
from IPython.core.display import HTML, display
x=captum.attr.visualization.format_word_importances(tokenizer.convert_ids_to_tokens(inp[0][0]),attrs_sum)
HTML(x)
# Out:
# <td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> When                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> University                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> Tu                    </font></mark><mark style="background-color: h
# ...
